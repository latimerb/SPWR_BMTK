# %%
# %matplotlib notebook
from bmtk.analyzer import nodes_table
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pdb
from mpl_toolkits.mplot3d import Axes3D
import h5py
import networkx as nx

num_PN = 8230
num_PV = 1646
num_Chn = 411

# Load the files
nodes_info = nodes_table(nodes_file='network/SPWR_biophysical_nodes.h5', population='SPWR_biophysical')
edges_info = h5py.File('network/SPWR_biophysical_SPWR_biophysical_edges.h5')

# Get positions
dset = np.array(nodes_info['positions'].values)

# Convert positions to a dictionary
pos_df = pd.DataFrame(np.array(list(dset))[:,0:2])
pos_df_t = pos_df.transpose()

pos = pos_df_t.to_dict(orient='list')



# Plot
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.scatter(pos_ds[num_PN+num_PV:num_PN+num_PV+num_Chn-1,0],pos_ds[num_PN+num_PV:num_PN+num_PV+num_Chn-1,1],pos_ds[num_PN+num_PV:num_PN+num_PV+num_Chn-1,2],color='blue')
ax.scatter(pos_ds[0:num_PN-1,0],pos_ds[0:num_PN-1,1],pos_ds[0:num_PN-1,2],color=[1,0,0])
ax.scatter(pos_ds[num_PN:num_PN+num_PV-1,0],pos_ds[num_PN:num_PN+num_PV-1,1],pos_ds[num_PN:num_PN+num_PV-1,2],color=[0,1,0])
plt.title('entire network')

fig2 = plt.figure(figsize=(7,5))
ax2 = fig2.add_subplot(1, 1, 1, projection='3d')
ax2.scatter(pos_ds[num_PN+num_PV:num_PN+num_PV+num_Chn-1,0],pos_ds[num_PN+num_PV:num_PN+num_PV+num_Chn-1,1],pos_ds[num_PN+num_PV:num_PN+num_PV+num_Chn-1,2],color='blue')
plt.title('chandeliers')
# Out:
# /home/ben/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# <div id='75f6d05f-459b-4add-89ba-5b86a1019b2a'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c97d311f8176> in <module>()
#      31 fig = plt.figure(figsize=(7,5))
#      32 ax = fig.add_subplot(1, 1, 1, projection='3d')
# ---> 33 ax.scatter(pos_ds[num_PN+num_PV:num_PN+num_PV+num_Chn-1,0],pos_ds[num_PN+num_PV:num_PN+num_PV+num_Chn-1,1],pos_ds[num_PN+num_PV:num_PN+num_PV+num_Chn-1,2],color='blue')
#      34 ax.scatter(pos_ds[0:num_PN-1,0],pos_ds[0:num_PN-1,1],pos_ds[0:num_PN-1,2],color=[1,0,0])
# ...

# %%
cell_of_interest = 100

# Get connections
sources = edges_info['edges']['SPWR_biophysical_to_SPWR_biophysical']['source_node_id'].value
targets = edges_info['edges']['SPWR_biophysical_to_SPWR_biophysical']['target_node_id'].value
connections = pd.DataFrame({'source':sources[sources==cell_of_interest], 'target':targets[sources==cell_of_interest]})

# Build a graph
G = nx.from_pandas_edgelist(connections, edge_attr=True)

# nodelist - nodes to plot
# colorlist - colors of those nodes
nodelist = []
colorlist = []
nodelist.append(cell_of_interest)
if cell_of_interest < num_PN:
    colorlist.append('#FF0000')
elif cell_of_interest < num_PV:
    colorlist.append('#00FF00')
else:
    colorlist.append('#0000FF')
for i in np.arange(0,connections.shape[0]):
    nodelist.append(connections['target'].iloc[i])
    if connections['target'].iloc[i] < num_PN:
        colorlist.append('#FF0000')
    elif connections['target'].iloc[i] < num_PV:
        colorlist.append('#00FF00')
    else:
        colorlist.append('#0000FF')

fig3 = plt.figure(figsize=(7,5))
nx.draw_networkx(G,pos,with_labels=False,node_size=50,nodelist=nodelist,node_color=colorlist)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
